# %%
from fastai import * 
from fastbook import *
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

# %%
bear_id = learner.load_learner('02_scripts/bear_identifier.pkl')

# %%
#get images
bear = search_images_ddg('grizzly bear', max_images=1)
bear_image = download_url(bear[0])
bear_image = PILImage.create(bear_image)
bear_image.show()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='319488' class='' max='312380' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       102.28% [319488/312380 00:00<00:00]
#     </div>
# <AxesSubplot:>

# %%
bear_id.predict(bear_image)
# Out:
# ('grizzly', tensor(1), tensor([7.2365e-03, 9.9272e-01, 4.3302e-05]))
